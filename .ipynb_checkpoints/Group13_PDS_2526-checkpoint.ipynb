# %% [markdown]
# ### Library Installation

# %%
#!pip install pandas
#!pip install scikit-learn
#!pip install beautifulsoup4  
#!pip install selenium
#!pip install requests

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### File Importing

# %%
df = pd.read_csv("city_data.csv", delimiter='|')
df.head()
# Out:
#           Unnamed: 0          Unnamed: 1  Unnamed: 2               Unnamed: 3  \
# 0               City  Population Density  Population  Working Age Population
# 1    Vienna, Austria                 310     2983513                  2018818
# 2  Salzburg, Austria                 243      375489                   250472
# 3  Brussels, Belgium                 681     3284548                  2137425
# 4   Antwerp, Belgium                 928     1139663                   723396
#
#                Unnamed: 4         Unnamed: 5      Unnamed: 6  \
# 0  Youth Dependency Ratio  Unemployment Rate  GDP per Capita
# 1                    20.1               10.2           55770
# 2                    20.3                  3           66689
# 3                    27.5               10.7           62500
# 4                    27.7                6.2           57595
#
#                         Unnamed: 7                         Unnamed: 8  \
# 0  Days of very strong heat stress              Main Spoken Languages
# 1                                3  German, English, Turkish, Serbian
# 2                                0                             German
# 3                                3     French, Dutch, Arabic, English
# 4                                3              Dutch, French, Arabic
#
#                Unnamed: 9          Unnamed: 10             Unnamed: 11  \
# 0  Average Monthly Salary  Avgerage Rent Price  Average Cost of Living
# 1                    2500                 1050                    2061
# 2                    3200                 1100                    2186
# 3                    3350                 1200                    1900
# 4                    2609                  900                    1953
#
#                Unnamed: 12          Unnamed: 13
# 0  Average Price Groceries     Last Data Update
# 1                      340  2024-06-15 00:00:00
# 2                      NaN  2023-11-03 00:00:00
# 3                      NaN  2023-04-22 00:00:00
# 4                      NaN  2024-08-09 00:00:00

# %% [markdown]
# ### Header Correction

# %%
new_header = df.iloc[0]

df.columns = new_header
df = df[1:]

df.head()
# Out:
# 0               City Population Density Population Working Age Population   \
# 1    Vienna, Austria                310    2983513                 2018818
# 2  Salzburg, Austria                243     375489                  250472
# 3  Brussels, Belgium                681    3284548                 2137425
# 4   Antwerp, Belgium                928    1139663                  723396
# 5      Gent, Belgium                552     645813                  417832
#
# 0 Youth Dependency Ratio Unemployment Rate GDP per Capita  \
# 1                   20.1              10.2          55770
# 2                   20.3                 3          66689
# 3                   27.5              10.7          62500
# 4                   27.7               6.2          57595
# 5                   24.8               NaN          53311
#
# 0 Days of very strong heat stress              Main Spoken Languages  \
# 1                               3  German, English, Turkish, Serbian
# 2                               0                             German
# 3                               3     French, Dutch, Arabic, English
# 4                               3              Dutch, French, Arabic
# 5                               2                      Dutch, French
#
# 0 Average Monthly Salary Avgerage Rent Price Average Cost of Living  \
# 1                   2500                1050                   2061
# 2                   3200                1100                   2186
# 3                   3350                1200                   1900
# 4                   2609                 900                   1953
# 5                   2400                 827                   1200
#
# 0 Average Price Groceries     Last Data Update
# 1                     340  2024-06-15 00:00:00
# 2                     NaN  2023-11-03 00:00:00
# 3                     NaN  2023-04-22 00:00:00
# 4                     NaN  2024-08-09 00:00:00
# 5                     120  2023-07-17 00:00:00

# %% [markdown]
# ## Data Type Correction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 1 to 86
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             86 non-null     object
#  1   Population Density               85 non-null     object
#  2   Population                       86 non-null     object
#  3   Working Age Population           85 non-null     object
#  4   Youth Dependency Ratio           86 non-null     object
#  5   Unemployment Rate                85 non-null     object
#  6   GDP per Capita                   85 non-null     object
#  7   Days of very strong heat stress  86 non-null     object
#  8   Main Spoken Languages            85 non-null     object
#  9   Average Monthly Salary           86 non-null     object
#  10  Avgerage Rent Price              86 non-null     object
#  11  Average Cost of Living           86 non-null     object
#  12  Average Price Groceries          6 non-null      object
#  13  Last Data Update                 86 non-null     object
# dtypes: object(14)
# memory usage: 9.5+ KB

# %%
i8min, i8max, i16min, i16max, i32min, i32max, i64min, i64max = np.iinfo(np.int8).min, np.iinfo(np.int8).max, np.iinfo(np.int16).min, np.iinfo(np.int16).max, np.iinfo(np.int32).min, np.iinfo(np.int32).max, np.iinfo(np.int64).min, np.iinfo(np.int64).max
print(f'int8:[{i8min}, {i8max}]')
print(f'int16:[{i16min}, {i16max}]')
print(f'int32:[{i32min}, {i32max}]')
print(f'int64:[{i64min}, {i64max}]')
    
    
f16min, f16max, f32min, f32max, f64min, f64max = np.finfo(np.float16).min, np.finfo(np.float16).max, np.finfo(np.float32).min, np.finfo(np.float32).max, np.finfo(np.float64).min, np.finfo(np.float64).max
#float8 doesn't exist
print(f'float16:[{f16min}, {f16max}]')
print(f'float32:[{f32min}, {f32max}]')
print(f'float64:[{f64min}, {f64max}]')
# Out:
# int8:[-128, 127]
# int16:[-32768, 32767]
# int32:[-2147483648, 2147483647]
# int64:[-9223372036854775808, 9223372036854775807]
# float16:[-65504.0, 65504.0]
# float32:[-3.4028234663852886e+38, 3.4028234663852886e+38]
# float64:[-1.7976931348623157e+308, 1.7976931348623157e+308]

# %%
df = df.astype({'City': 'category',
                    'Population Density': 'float16',
                    'Population': 'int32',
                    'Working Age Population ': 'float32',
                    'Youth Dependency Ratio': 'float16',
                    'Unemployment Rate': 'float16',
                    'GDP per Capita': 'float32',
                    'Days of very strong heat stress': 'int8',
                    'Main Spoken Languages': 'category',
                    'Average Monthly Salary': 'int16',
                    'Avgerage Rent Price': 'int16',
                    'Average Cost of Living': 'int16',
                    'Average Price Groceries': 'float16',
                    'Last Data Update': 'datetime64[ns]'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 1 to 86
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             86 non-null     category
#  1   Population Density               85 non-null     float16
#  2   Population                       86 non-null     int32
#  3   Working Age Population           85 non-null     float32
#  4   Youth Dependency Ratio           86 non-null     float16
#  5   Unemployment Rate                85 non-null     float16
#  6   GDP per Capita                   85 non-null     float32
#  7   Days of very strong heat stress  86 non-null     int8
#  8   Main Spoken Languages            85 non-null     category
#  9   Average Monthly Salary           86 non-null     int16
#  10  Avgerage Rent Price              86 non-null     int16
#  11  Average Cost of Living           86 non-null     int16
#  12  Average Price Groceries          6 non-null      float16
#  13  Last Data Update                 86 non-null     datetime64[ns]
# dtypes: category(2), datetime64[ns](1), float16(4), float32(2), int16(3), int32(1), int8(1)
# memory usage: 8.4 KB

# %% [markdown]
# ## Data Wrangling and Analysis

# %% [markdown]
# 1. How did you handle missing values and duplicate records in the dataset? Justify your approach.

# %% [markdown]
# <font size = '4'> <b> City Mismatch <b>

# %% [markdown]
# First of all, we need to solve the mismatch in *City* column, separating the city name from the country to which it belongs.

# %% [markdown]
# The problem is that not all pairs in the City collumn have the same formatting.

# %%
temp = df.copy()
print(temp.iloc[2,0])
print(temp.iloc[12,0])
print(temp.iloc[15,0])
print(temp.iloc[38,0])
# Out:
# Brussels, Belgium
# Lemesos;Cyprus
# Berlin. Germany
# Lyon,  France

# %% [markdown]
# So we will correct it by replacing the formatting errors such as ';', '.' and double spaces with the same ', '.

# %%
corrected = []
for city in temp.City:
    if ';' in city:
        corrected.append(city.replace(';', ', '))
    elif '.'in city:
        corrected.append(city.replace('.', ','))
    elif '  ' in city:
        corrected.append(city.replace('  ', ' '))
    else:
        corrected.append(city)

temp.City = corrected

print(temp.iloc[2,0])
print(temp.iloc[12,0])
print(temp.iloc[15,0])
print(temp.iloc[38,0])
# Out:
# Brussels, Belgium
# Lemesos, Cyprus
# Berlin, Germany
# Lyon, France

# %% [markdown]
# Another problem is that in row 45 the pair is in 'country, city' format instead of 'city, country', we can solve it by manually correcting it.

# %%
temp.iloc[45]
# Out:
# 0
# City                                    Greece, Athens
# Population Density                              1829.0
# Population                                     3530371
# Working Age Population                       2287174.0
# Youth Dependency Ratio                            22.0
# Unemployment Rate                            17.203125
# GDP per Capita                                 38580.0
# Days of very strong heat stress                     17
# Main Spoken Languages                   Greek, English
# Average Monthly Salary                            1050
# Avgerage Rent Price                                600
# Average Cost of Living                            1200
# Average Price Groceries                            NaN
# Last Data Update                   2024-07-16 00:00:00
# Name: 46, dtype: object

# %%
temp.iloc[45, 0] = 'Athens, Greece'

temp.iloc[45]
# Out:
# 0
# City                                    Athens, Greece
# Population Density                              1829.0
# Population                                     3530371
# Working Age Population                       2287174.0
# Youth Dependency Ratio                            22.0
# Unemployment Rate                            17.203125
# GDP per Capita                                 38580.0
# Days of very strong heat stress                     17
# Main Spoken Languages                   Greek, English
# Average Monthly Salary                            1050
# Avgerage Rent Price                                600
# Average Cost of Living                            1200
# Average Price Groceries                            NaN
# Last Data Update                   2024-07-16 00:00:00
# Name: 46, dtype: object

# %% [markdown]
# Now that all pairs have consistent formatting we can split the pairs in CityName and Country.

# %%
#Extract the country

pairs = [city.split(', ') for city in temp.City]

cities = [pair[0] for pair in pairs]
countries = [pair[1] for pair in pairs]

print(cities)
print(countries)
# Out:
# ['Vienna', 'Salzburg', 'Brussels', 'Antwerp', 'Gent', 'Bruges', 'Sofia', 'Dobrich', 'Zurich', 'Geneva', 'Basel', 'Lefkosia', 'Lemesos', 'Prague', 'Ostrava', 'Berlin', 'Berlin', 'Hamburg', 'Munich', 'Cologne', 'Frankfurt am Main', 'Stuttgart', 'Leipzig', 'Dresden', 'Dusseldorf', 'Hanover', 'Copenhagen', 'Odense', 'Madrid', 'Barcelona', 'Valencia', 'Seville', 'Malaga', 'Malaga', 'Tallinn', 'Helsinki', 'Tampere', 'Paris', 'Lyon', 'Toulouse', 'London', 'Leeds', 'Glasgow', 'Liverpool', 'Edinburgh', 'Athens', 'Thessaloniki', 'Zagreb', 'Split', 'Budapest', 'Miskolc', 'Debrecen', 'Dublin', 'Cork', 'Rome', 'Milan', 'Naples', 'Turin', 'Florence', 'Venice', 'Luxembourg', 'Riga', 'Malta', 'The Hague', 'Amsterdam', 'Rotterdam', 'Utrecht', 'Eindhoven', 'Oslo', 'Bergen', 'Stavanger', 'Warsaw', 'Lodz', 'Cracow', 'Lisbon', 'Porto', 'Braga', 'Coimbra', 'Giroc', 'Bratislava', 'Ljubljana', 'Stockholm', 'Gothenburg', 'Malmo', 'Ankara', 'Adana']
# ['Austria', 'Austria', 'Belgium', 'Belgium', 'Belgium', 'Belgium', 'Bulgaria', 'Bulgaria', 'Switzerland', 'Switzerland', 'Switzerland', 'Cyprus', 'Cyprus', 'Czechia', 'Czechia', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Denmark', 'Denmark', 'Spain', 'Spain', 'Spain', 'Spain', 'Spain', 'Spain', 'Estonia', 'Finland', 'Finland', 'France', 'France', 'France', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'United Kingdom', 'Greece', 'Greece', 'Croatia', 'Croatia', 'Hungary', 'Hungary', 'Hungary', 'Ireland', 'Ireland', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Luxembourg', 'Latvia', 'Malta', 'Netherlands', 'Netherlands', 'Netherlands', 'Netherlands', 'Netherlands', 'Norway', 'Norway', 'Norway', 'Poland', 'Poland', 'Poland', 'Portugal', 'Portugal', 'Portugal', 'Portugal', 'Romania', 'Slovak Republic', 'Slovenia', 'Sweden', 'Sweden', 'Sweden', 'Turkiye', 'Turkiye']

# %% [markdown]
# Now that we have the cities and country lists we can add them to the dataframe.

# %%
temp['CityName'] = cities
temp['Country'] = countries

temp.loc[:,['City', 'CityName', 'Country']]
# Out:
# 0                 City    CityName  Country
# 1      Vienna, Austria      Vienna  Austria
# 2    Salzburg, Austria    Salzburg  Austria
# 3    Brussels, Belgium    Brussels  Belgium
# 4     Antwerp, Belgium     Antwerp  Belgium
# 5        Gent, Belgium        Gent  Belgium
# ..                 ...         ...      ...
# 82   Stockholm, Sweden   Stockholm   Sweden
# 83  Gothenburg, Sweden  Gothenburg   Sweden
# 84       Malmo, Sweden       Malmo   Sweden
# 85     Ankara, Turkiye      Ankara  Turkiye
# 86      Adana, Turkiye       Adana  Turkiye
#
# [86 rows x 3 columns]

# %% [markdown]
# <font size = '4'> <b> Duplicates <b>

# %% [markdown]
# As we can see anothor problem arises, there are cities that are duplicated in the dataset.

# %%
temp[temp.duplicated(keep=False)]
# Out:
# C:\Users\Ines Caseiro\AppData\Roaming\Python\Python313\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# 0              City  Population Density  Population  Working Age Population   \
# 16  Berlin, Germany               304.0     5303922                3481212.0
# 17  Berlin, Germany               304.0     5303922                3481212.0
# 33    Malaga, Spain               571.0      869096                 585608.0
# 34    Malaga, Spain               571.0      869096                 585608.0
#
# 0   Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# 16               21.296875           4.699219         46548.0
# 17               21.296875           4.699219         46548.0
# 33               23.500000          17.703125         27694.0
# 34               23.500000          17.703125         27694.0
#
# 0   Days of very strong heat stress             Main Spoken Languages  \
# 16                                3  German, Turkish, Arabic, English
# 17                                3  German, Turkish, Arabic, English
# 33                                0                  Spanish, English
# 34                                0                  Spanish, English
#
# 0   Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 16                    3200                 1220                    2200
# 17                    3200                 1220                    2200
# 33                    2200                 1312                    1400
# 34                    2200                 1312                    1400
#
# 0   Average Price Groceries Last Data Update CityName  Country
# 16                      NaN       2023-06-29   Berlin  Germany
# 17                      NaN       2023-06-29   Berlin  Germany
# 33                      NaN       2023-11-27   Malaga    Spain
# 34                      NaN       2023-11-27   Malaga    Spain

# %% [markdown]
# So we will drop the second occurence of each of these cities.

# %%
temp.drop_duplicates(inplace=True)

temp[temp.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [City, Population Density, Population, Working Age Population , Youth Dependency Ratio, Unemployment Rate, GDP per Capita, Days of very strong heat stress, Main Spoken Languages, Average Monthly Salary, Avgerage Rent Price, Average Cost of Living, Average Price Groceries, Last Data Update, CityName, Country]
# Index: []

# %% [markdown]
# We just need to check if there is a duplicated city name in the dataset with different data associated with it. As we can check in the following output this doesn't happen in our dataset

# %%
temp[temp.duplicated(subset=['CityName'])]
# Out:
# Empty DataFrame
# Columns: [City, Population Density, Population, Working Age Population , Youth Dependency Ratio, Unemployment Rate, GDP per Capita, Days of very strong heat stress, Main Spoken Languages, Average Monthly Salary, Avgerage Rent Price, Average Cost of Living, Average Price Groceries, Last Data Update, CityName, Country]
# Index: []

# %% [markdown]
# Now we can make the changes to our DataFrame permanent by applying them to the original DataFrame.

# %%
df = temp

# %% [markdown]
# <font size = '4'> <b> Missing values <b>

# %%
df['Average Price Groceries'].value_counts()
# Out:
# Average Price Groceries
# 340.0    1
# 120.0    1
# 230.0    1
# 256.0    1
# 100.0    1
# 309.0    1
# Name: count, dtype: int64

# %% [markdown]
# As the column *'Average Price Groceries'* has only 6 values (out of 86) and it would not be needed, we opted for eliminate it.

# %%
df.drop('Average Price Groceries', axis = 1, inplace = True)

# %%
df[df.isna().any(axis = 1)]
# Out:
# C:\Users\Ines Caseiro\AppData\Roaming\Python\Python313\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# 0                  City  Population Density  Population  \
# 5         Gent, Belgium               552.0      645813
# 13      Lemesos, Cyprus               190.0      262238
# 25  Dusseldorf, Germany              1295.0     1554077
# 31      Valencia, Spain                 NaN     1748142
#
# 0   Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 5                  417832.0               24.796875                NaN
# 13                 173906.0               23.062500          11.203125
# 25                      NaN               21.406250           3.300781
# 31                1162828.0               22.593750          13.703125
#
# 0   GDP per Capita  Days of very strong heat stress    Main Spoken Languages  \
# 5          53311.0                                2            Dutch, French
# 13             NaN                                0  Greek, English, Russian
# 25         71238.0                                3                      NaN
# 31         33570.0                                5        Spanish;Valencian
#
# 0   Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 5                     2400                  827                    1200
# 13                    2500                 1400                    2300
# 25                    3200                 1100                    2050
# 31                    2400                 1190                    1300
#
# 0  Last Data Update    CityName  Country
# 5        2023-07-17        Gent  Belgium
# 13       2023-08-14     Lemesos   Cyprus
# 25       2024-01-15  Dusseldorf  Germany
# 31       2023-06-04    Valencia    Spain

# %% [markdown]
# For the numeric missing values (*Population Density*,*Working Age Population*, *Unemployment Rate* and *GPD per Capita*), we will use KNN Imputer to fill them. For the categorical (*Main Spoken Languages*), we decided to fill based on online research.

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

numeric_columns = df.select_dtypes(include = 'number').columns
numeric_data = df[numeric_columns]
non_numeric = df.drop(numeric_columns, axis = 1)

original_index = df.index

#Scale the data
scaler = StandardScaler()
numeric_scaled = scaler.fit_transform(numeric_data)

#Imputing missing values
imputer = KNNImputer(n_neighbors = 5, weights = 'distance')
numeric_imputed_scaled = imputer.fit_transform(numeric_scaled)

#Reverse the scaling back to the original values
numeric_imputed = scaler.inverse_transform(numeric_imputed_scaled) # array

numeric_df = pd.DataFrame(numeric_imputed, columns = numeric_columns, index = original_index)

#Join the numeric and non-numeric datasets
temp = pd.concat([non_numeric[['City', 'CityName', 'Country']],
                     numeric_df.iloc[:,:7],
                     non_numeric['Main Spoken Languages'],
                     numeric_df.iloc[:,7:],
                     non_numeric['Last Data Update']], axis = 1)
df = temp

# %% [markdown]
# The missing value at the *Main Spoken Languages* is in Dusseldorf, a German city. We conducted some research online and found that this city is among the top German cities where English is spoken. From the cities in our dataset, those English-speaking cities are marked as such, so we decided to fill the missing value with both languages (German and English).

# %%
#Missing value at column Main Spoken Languages (column 10) at line of index 25
df.fillna({'Main Spoken Languages':'German, English'}, inplace = True)

# %%
df[df.isna().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [City, CityName, Country, Population Density, Population, Working Age Population , Youth Dependency Ratio, Unemployment Rate, GDP per Capita, Days of very strong heat stress, Main Spoken Languages, Average Monthly Salary, Avgerage Rent Price, Average Cost of Living, Last Data Update]
# Index: []

# %%
#check the previous missing values lines
df.loc[[5,13,25,31]]
# Out:
#                    City    CityName  Country  Population Density  Population  \
# 5         Gent, Belgium        Gent  Belgium          552.000000    645813.0
# 13      Lemesos, Cyprus     Lemesos   Cyprus          190.000000    262238.0
# 25  Dusseldorf, Germany  Dusseldorf  Germany         1295.000000   1554077.0
# 31      Valencia, Spain    Valencia    Spain          536.136838   1748142.0
#
#     Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 5              4.178320e+05               24.796875           4.587669
# 13             1.739060e+05               23.062500          11.203125
# 25             9.895829e+05               21.406250           3.300781
# 31             1.162828e+06               22.593750          13.703125
#
#     GDP per Capita  Days of very strong heat stress    Main Spoken Languages  \
# 5     53311.000000                              2.0            Dutch, French
# 13    46723.931277                              0.0  Greek, English, Russian
# 25    71238.000000                              3.0          German, English
# 31    33570.000000                              5.0        Spanish;Valencian
#
#     Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 5                   2400.0                827.0                  1200.0
# 13                  2500.0               1400.0                  2300.0
# 25                  3200.0               1100.0                  2050.0
# 31                  2400.0               1190.0                  1300.0
#
#    Last Data Update
# 5        2023-07-17
# 13       2023-08-14
# 25       2024-01-15
# 31       2023-06-04

# %% [markdown]
# In the previuos output, we can see that the type of the columns has changed. So, we need to repeat the process.

# %%
df = df.astype({'City': 'category',
                'CityName': 'category',
                'Country': 'category',
                'Population Density': 'float16',
                'Population': 'int32',
                'Working Age Population ': 'float32',
                'Youth Dependency Ratio': 'float16',
                'Unemployment Rate': 'float16',
                'GDP per Capita': 'float32',
                'Days of very strong heat stress': 'int8',
                'Main Spoken Languages': 'category',
                'Average Monthly Salary': 'int16',
                'Avgerage Rent Price': 'int16',
                'Average Cost of Living': 'int16',
                'Last Data Update': 'datetime64[ns]'})

df.head()
# Out:
# C:\Users\Ines Caseiro\AppData\Roaming\Python\Python313\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#                 City  CityName  Country  Population Density  Population  \
# 1    Vienna, Austria    Vienna  Austria               310.0     2983513
# 2  Salzburg, Austria  Salzburg  Austria               243.0      375489
# 3  Brussels, Belgium  Brussels  Belgium               681.0     3284548
# 4   Antwerp, Belgium   Antwerp  Belgium               928.0     1139663
# 5      Gent, Belgium      Gent  Belgium               552.0      645813
#
#    Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 1                2018818.0               20.093750          10.203125
# 2                 250472.0               20.296875           3.000000
# 3                2137425.0               27.500000          10.703125
# 4                 723396.0               27.703125           6.199219
# 5                 417832.0               24.796875           4.585938
#
#    GDP per Capita  Days of very strong heat stress  \
# 1         55770.0                                3
# 2         66689.0                                0
# 3         62500.0                                3
# 4         57595.0                                3
# 5         53311.0                                2
#
#                Main Spoken Languages  Average Monthly Salary  \
# 1  German, English, Turkish, Serbian                    2500
# 2                             German                    3200
# 3     French, Dutch, Arabic, English                    3350
# 4              Dutch, French, Arabic                    2609
# 5                      Dutch, French                    2400
#
#    Avgerage Rent Price  Average Cost of Living Last Data Update
# 1                 1050                    2061       2024-06-15
# 2                 1100                    2186       2023-11-03
# 3                 1200                    1900       2023-04-22
# 4                  900                    1953       2024-08-09
# 5                  827                    1200       2023-07-17

# %% [markdown]
# Now that all these details are solved, the rest of the analysis will be much smoother.

# %% [markdown]
# 2.
#
#         a) Which country appears most frequently in the dataset? How many cities are associated with it?

# %% [markdown]
# Finally we can count the name of rows (Cities) that have the same value in the 'Country' collumn.

# %%
df['Country'].value_counts()
# Out:
# Country
# Germany            10
# Italy               6
# Spain               5
# United Kingdom      5
# Netherlands         5
# Belgium             4
# Portugal            4
# Norway              3
# Sweden              3
# Poland              3
# France              3
# Hungary             3
# Switzerland         3
# Bulgaria            2
# Austria             2
# Ireland             2
# Finland             2
# Greece              2
# Denmark             2
# Croatia             2
# Cyprus              2
# Czechia             2
# Turkiye             2
# Estonia             1
# Malta               1
# Latvia              1
# Luxembourg          1
# Slovenia            1
# Romania             1
# Slovak Republic     1
# Name: count, dtype: int64

# %% [markdown]
# This way we can conclude that the most frequent country is Germany and it has 11 cities associated with it.

# %% [markdown]
#         b) How many cities are present in total? How many are associated with Greece?

# %% [markdown]
# As we solved duplicate entries in the previous item the number of cities in the dataset is the number of rows in our dataset.

# %% [markdown]
# df

# %% [markdown]
# As we can see at the bottom of the privious table there are 84 cities in our dataset.

# %% [markdown]
# As for the number of cities associated with Greece, there are 2 cities associated with Greece (as per the next output)

# %%
print(df.query('Country == "Greece"').shape[0], 'rows')
df.query('Country == "Greece"')
# Out:
# 2 rows
# C:\Users\Ines Caseiro\AppData\Roaming\Python\Python313\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#                     City      CityName Country  Population Density  \
# 46        Athens, Greece        Athens  Greece              1829.0
# 47  Thessaloniki, Greece  Thessaloniki  Greece               381.0
#
#     Population  Working Age Population   Youth Dependency Ratio  \
# 46     3530371                2287174.0               22.000000
# 47     1050568                 684564.0               22.203125
#
#     Unemployment Rate  GDP per Capita  Days of very strong heat stress  \
# 46          17.203125         38580.0                               17
# 47          19.906250         23940.0                               10
#
#    Main Spoken Languages  Average Monthly Salary  Avgerage Rent Price  \
# 46        Greek, English                    1050                  600
# 47                 Greek                    1000                  550
#
#     Average Cost of Living Last Data Update
# 46                    1200       2024-07-16
# 47                    1100       2023-12-21

# %% [markdown]
#         c) Which is the least spoken language in the dataset? Which are the top 3 most spoken languages?

# %%
df[['City', 'Main Spoken Languages']].head()
# Out:
#                 City              Main Spoken Languages
# 1    Vienna, Austria  German, English, Turkish, Serbian
# 2  Salzburg, Austria                             German
# 3  Brussels, Belgium     French, Dutch, Arabic, English
# 4   Antwerp, Belgium              Dutch, French, Arabic
# 5      Gent, Belgium                      Dutch, French

# %% [markdown]
# As we can see the `Most Spoken Language` column is formatted as a string of comma separated languages, so we will firstly need to convert it to a list of the languages spoken in that city.

# %%
temp = df.copy()

# %%
temp['Main Spoken Languages'] = temp['Main Spoken Languages'].astype(str).str.split(', ')

temp.head()
# Out:
#                 City  CityName  Country  Population Density  Population  \
# 1    Vienna, Austria    Vienna  Austria               310.0   2983513.0
# 2  Salzburg, Austria  Salzburg  Austria               243.0    375489.0
# 3  Brussels, Belgium  Brussels  Belgium               681.0   3284548.0
# 4   Antwerp, Belgium   Antwerp  Belgium               928.0   1139663.0
# 5      Gent, Belgium      Gent  Belgium               552.0    645813.0
#
#    Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 1                2018818.0               20.093750          10.203125
# 2                 250472.0               20.296875           3.000000
# 3                2137425.0               27.500000          10.703125
# 4                 723396.0               27.703125           6.199219
# 5                 417832.0               24.796875           4.587669
#
#    GDP per Capita  Days of very strong heat stress  \
# 1         55770.0                              3.0
# 2         66689.0                              0.0
# 3         62500.0                              3.0
# 4         57595.0                              3.0
# 5         53311.0                              2.0
#
#                  Main Spoken Languages  Average Monthly Salary  \
# 1  [German, English, Turkish, Serbian]                  2500.0
# 2                             [German]                  3200.0
# 3     [French, Dutch, Arabic, English]                  3350.0
# 4              [Dutch, French, Arabic]                  2609.0
# 5                      [Dutch, French]                  2400.0
#
#    Avgerage Rent Price  Average Cost of Living Last Data Update
# 1               1050.0                  2061.0       2024-06-15
# 2               1100.0                  2186.0       2023-11-03
# 3               1200.0                  1900.0       2023-04-22
# 4                900.0                  1953.0       2024-08-09
# 5                827.0                  1200.0       2023-07-17

# %% [markdown]
# Now that we have the languages in a list, we need to explode this collumn creating a new row for each language spoken in a city.

# %%
exploded_languages = temp.explode('Main Spoken Languages')

exploded_languages.head()
# Out:
#                 City  CityName  Country  Population Density  Population  \
# 1    Vienna, Austria    Vienna  Austria               310.0   2983513.0
# 1    Vienna, Austria    Vienna  Austria               310.0   2983513.0
# 1    Vienna, Austria    Vienna  Austria               310.0   2983513.0
# 1    Vienna, Austria    Vienna  Austria               310.0   2983513.0
# 2  Salzburg, Austria  Salzburg  Austria               243.0    375489.0
#
#    Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 1                2018818.0               20.093750          10.203125
# 1                2018818.0               20.093750          10.203125
# 1                2018818.0               20.093750          10.203125
# 1                2018818.0               20.093750          10.203125
# 2                 250472.0               20.296875           3.000000
#
#    GDP per Capita  Days of very strong heat stress Main Spoken Languages  \
# 1         55770.0                              3.0                German
# 1         55770.0                              3.0               English
# 1         55770.0                              3.0               Turkish
# 1         55770.0                              3.0               Serbian
# 2         66689.0                              0.0                German
#
#    Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 1                  2500.0               1050.0                  2061.0
# 1                  2500.0               1050.0                  2061.0
# 1                  2500.0               1050.0                  2061.0
# 1                  2500.0               1050.0                  2061.0
# 2                  3200.0               1100.0                  2186.0
#
#   Last Data Update
# 1       2024-06-15
# 1       2024-06-15
# 1       2024-06-15
# 1       2024-06-15
# 2       2023-11-03

# %% [markdown]
# Now we can finally check how many times each language apears in the `exploded_languages` dataframe.

# %%
exploded_languages['Main Spoken Languages'].value_counts()
# Out:
# Main Spoken Languages
# English              46
# German               14
# Turkish              10
# French               10
# Dutch                 9
# Italian               6
# Polish                4
# Swedish               4
# Greek                 4
# Spanish               4
# Portuguese            4
# Hungarian             3
# Arabic                3
# Norwegian             3
# Russian               3
# Irish Gaelic          2
# Urdu                  2
# Finnish               2
# Danish                2
# Bulgarian             2
# Czech                 2
# Croatian              2
# Serbian               1
#   Arabic              1
# Estonian              1
# nan                   1
# Catalan               1
# Spanish;Valencian     1
# Scots Gaelic          1
# Scots                 1
# Bengali               1
# Latvian               1
# Luxembourgish         1
# Maltese               1
# Romanian              1
# Slovak                1
# Slovene               1
# Name: count, dtype: int64

# %% [markdown]
# The least spoken language is Slovene and the 3 most spoken are English, German and Turkish.

# %% [markdown]
# 3.
#
#         a) Entries uploaded before April 2023 need to be updated. Which cities would require an update?

# %%
import datetime as dt
need_update_df = df[df['Last Data Update'] < dt.datetime(year = 2023, month = 4, day = 1)]
cities = need_update_df['CityName'].to_list()
cities
# Out:
# ['Basel', 'Munich', 'Frankfurt am Main', 'Lyon', 'Venice', 'Gothenburg']

# %% [markdown]
# Basel, Munich, Frankfurt am Main, Lyon, Venice and Gothenburg would require an update.

# %% [markdown]
#         b) How many days ago was the last update? On what day, month, and year did it occur?

# %%
now = dt.datetime.now() #to calculate the distance

df['Year Last Update'] = df['Last Data Update'].dt.year
df['Month Last Update'] = df['Last Data Update'].dt.month
df['Day Last Update'] = df['Last Data Update'].dt.day
df['Number Days Ago'] = (now - df['Last Data Update']).dt.days

#Show results
df[['CityName', 'Last Data Update', 'Year Last Update', 'Month Last Update', 'Day Last Update', 'Number Days Ago']]
# Out:
#       CityName Last Data Update  Year Last Update  Month Last Update  \
# 1       Vienna       2024-06-15              2024                  6
# 2     Salzburg       2023-11-03              2023                 11
# 3     Brussels       2023-04-22              2023                  4
# 4      Antwerp       2024-08-09              2024                  8
# 5         Gent       2023-07-17              2023                  7
# ..         ...              ...               ...                ...
# 82   Stockholm       2024-09-11              2024                  9
# 83  Gothenburg       2023-03-10              2023                  3
# 84       Malmo       2024-07-07              2024                  7
# 85      Ankara       2023-06-08              2023                  6
# 86       Adana       2024-05-02              2024                  5
#
#     Day Last Update  Number Days Ago
# 1                15              526
# 2                 3              751
# 3                22              946
# 4                 9              471
# 5                17              860
# ..              ...              ...
# 82               11              438
# 83               10              989
# 84                7              504
# 85                8              899
# 86                2              570
#
# [84 rows x 6 columns]

# %% [markdown]
# 4.
#
#         a) How are the Unemployment Rate and GDP per Capita distributed and related? What does this relationship suggest? Provide a visual representation.

# %%
# Import libraries and define the alias
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
#plotly importation
import plotly.express as px #plotly express
import plotly.graph_objects as go #plotly graph objects

# %%
x = df['GDP per Capita'].astype('float32').dropna()
y = df['Unemployment Rate'].astype('float32').dropna()

# linear regression
slope, intercept = np.polyfit(x, y, 1)
y_fit = slope * x + intercept

fig = go.Figure()

fig.add_trace(go.Scatter(x = x, y = y, mode='markers', marker=dict(color="#914678", size=10), name = 'Relation'))

# trendline
fig.add_trace(go.Scatter(x=x, y=y_fit, mode='lines', line=dict(color = "#58F011", width=2), name='Trendline'))

fig.update_layout(title = dict(text="<b>GDP per Capita and Unemployment Rate Distribution</b>",  
                               font=dict(family='Arial', size=20, color='#000000'),
                               xanchor = 'center', x = 0.5, yanchor='top', y=0.9),)

fig.update_xaxes(title_text='GDP per Capita', title_font=dict(family='Arial', size=12, color='#000000'))

fig.update_yaxes(title_text='Unemployment Rate', title_font=dict(family='Arial', size=12, color='#000000'))

fig.show()

# %% [markdown]
# The relation between the Unemployent Rate and the GDP per Capita suggests that in cities with a higher Unemployment Rate the GDP per Capita is lower.

# %% [markdown]
#         b) Which are the top 5 cities with the largest difference between the Average Monthly Salary and Average Cost of Living?
#         What about the top 5 countries with the smallest average difference?
#         Show these results with meaningful visualizations.

# %%
city_data_copy = df.copy()

# %%
city_data_copy['Average Savings'] = city_data_copy['Average Monthly Salary'] - city_data_copy['Average Cost of Living']

# %%
city_data_sorted = city_data_copy.sort_values(by='Average Savings')
fig = go.Figure()
fig.add_trace(go.Bar(x = city_data_sorted['CityName'], y = city_data_sorted['Average Savings'], 
                     marker=dict(color="#F011A6"),))
fig.update_layout(xaxis_title = 'City', yaxis_title = 'Difference', width=1300, height=500)
fig.update_layout(title = dict(text="<b>Difference between Average Monthly Salary and Average Cost of Living by City</b>",  
                               font=dict(family='Arial', size=17, color='#000000'),
                               xanchor = 'center', x = 0.5, yanchor='top', y=0.9),)
fig.update_layout(font = dict(size = 10))
fig.show()

# %% [markdown]
# The top 5 cities with the largest difference between the Average Monthly Salary and Average Cost of Living are (in descending order):
# Basel, Tampere, Helsinki, Zurich and Geneve.

# %%
savings_per_country = pd.pivot_table(city_data_copy, index='Country', 
                                    values='Average Savings', 
                                    aggfunc={'Average Savings':'mean'}).round(2).reset_index()
savings_per_country.head()
# Out:
# C:\Users\Ines Caseiro\AppData\Local\Temp\ipykernel_23844\1147709614.py:1: FutureWarning:
#
# The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#     Country  Average Savings
# 0   Austria            726.5
# 1   Belgium           1074.5
# 2  Bulgaria            150.0
# 3   Croatia            245.0
# 4    Cyprus            168.0

# %%
savings_per_country_sorted = savings_per_country.sort_values(by='Average Savings')
fig = go.Figure()
fig.add_trace(go.Bar(x = savings_per_country_sorted['Country'], y = savings_per_country_sorted['Average Savings'], 
                     marker=dict(color="#A2F011")))
fig.update_layout(xaxis_title = 'Country', yaxis_title = 'Difference', width=900, height=500)
fig.update_layout(title = dict(text="<b>Difference between Average Monthly Salary and Average Cost of Living by Country</b>",  
                               font=dict(family='Arial', size=17, color='#000000'),
                               xanchor = 'center', x = 0.5, yanchor='top', y=0.9))
fig.show()

# %% [markdown]
# The top 5 countries with the smallest average difference are (in ascending order):
# Portugal, Greece, Slovak Republic, Turkiye and Poland.

# %% [markdown]
#         c) Which is the best city for someone seeking:
#                 an average monthly salary above €1600,
#                 a cost of living below €900, and
#                 a country suitable for starting a family (with a    relatively larger youth population)?

# %%
city_data_filtered = city_data_copy[(city_data_copy['Average Monthly Salary'] > 2000)]
city_data_filtered = city_data_filtered[(city_data_filtered['Average Cost of Living'] <= 1600)]
city_data_filtered_sorted = city_data_filtered.sort_values(by = 'Unemployment Rate')
city_data_filtered_sorted[['City', 'Average Monthly Salary', 'Average Cost of Living', 'Unemployment Rate']]
# Out:
# C:\Users\Ines Caseiro\AppData\Roaming\Python\Python313\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning:
#
# overflow encountered in cast
#                 City  Average Monthly Salary  Average Cost of Living  \
# 24  Dresden, Germany                    3050                    1530
# 23  Leipzig, Germany                    2800                    1600
# 5      Gent, Belgium                    2400                    1200
# 37  Tampere, Finland                    3500                    1600
# 40  Toulouse, France                    2600                    1600
# 29     Madrid, Spain                    2271                    1589
# 31   Valencia, Spain                    2400                    1300
# 33     Malaga, Spain                    2200                    1400
# 32    Seville, Spain                    2300                    1150
#
#     Unemployment Rate
# 24           3.800781
# 23           4.300781
# 5            4.585938
# 37           6.601562
# 40           8.500000
# 29          10.796875
# 31          13.703125
# 33          17.703125
# 32          21.593750

# %% [markdown]
# The best city for someone seeking those specific conditions is Dresden, Germany.

# %% [markdown]
# 5. What are three additional insights you find meaningful when comparing the given cities?

# %% [markdown]
# ## Advanced Topic - Building an Interactive Map

# %% [markdown]
# ### 1. Web Scraping

# %% [markdown]
# To get the exact geographical coordinates for each city we need to webscrape for each city's wikipedia entry and from there get the latitude and longitude for each of them.

# %% [markdown]
# #### Importing Libraries needed for web scrapping

# %%
from bs4 import BeautifulSoup               # process html
from selenium import webdriver              # automate web browser interaction
from selenium.webdriver.common.by import By # specify specify how to locate elements on a web page.
import time                                 # set time delays

# %% [markdown]
# #### Create a browser instance

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# The following lines of code were needed for the browser to not crash
options = Options()
options.add_argument("--headless=new")
options.add_argument("--window-size=1920,1080")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--disable-gpu")
options.add_argument("--disable-software-rasterizer")


browser = webdriver.Chrome(options=options) # creates a new instance of a Chrome browser

url = 'https://en.wikipedia.org/wiki/Main_Page'

# %% [markdown]
# #### Get the city's coordinates

# %%
latitudes = []
longitudes = []

for i in df['City']:
    
    browser.get(url) # opens the main wikipedia page

    searchbox = browser.find_element(By.CLASS_NAME, 'cdx-text-input__input') # finds the wikepedia search bar
    searchbox.clear() # clears all previous inputs from the search bar
    searchbox.send_keys(i) # inserts the city + country into the searchbar
    time.sleep(2)

    firstresult = browser.find_element(By.CLASS_NAME, 'cdx-menu-item__content') # finds the first suggested result
    firstresult.click() # clicks on the first suggestion
    time.sleep(2)
    
    #If the link leads to a search result page instead of a city page, we neet the first result
    page_title = browser.title
    if "Search results" in page_title:
        results = browser.find_elements(By.CSS_SELECTOR, ".mw-search-result-heading a") # finds the first result
        if results:
            results[0].click() # clicks on it
            time.sleep(2)
    
    html_source = browser.page_source # gets the page source code
    print(browser.title)
    
    soupObj = BeautifulSoup(html_source, 'html.parser') # parses the source code into a soup object

    latitude = soupObj.find(attrs={"class": 'latitude'}).text   # gets the city latitude
    longitude = soupObj.find(attrs={"class": 'longitude'}).text # gets the city latitude

    latitudes.append(latitude)   # saves the city latitude into a list
    longitudes.append(longitude) # saves the city longitude into a list
# Out:
# Vienna - Wikipedia
# Salzburg - Wikipedia
# Brussels - Wikipedia
# Antwerp - Wikipedia
# Ghent - Wikipedia
# Bruges - Wikipedia
# Sofia - Wikipedia
# Dobrich - Wikipedia
# Zurich - Wikipedia
# Geneva - Wikipedia
# Basel - Wikipedia
# Nicosia - Wikipedia
# Limassol - Wikipedia
# Prague - Wikipedia
# Ostrava - Wikipedia
# Berlin - Wikipedia
# Hamburg - Wikipedia
# Munich - Wikipedia
# Cologne - Wikipedia
# Frankfurt - Wikipedia
# Stuttgart - Wikipedia
# Leipzig - Wikipedia
# Dresden - Wikipedia
# Düsseldorf - Wikipedia
# Hanover - Wikipedia
# Copenhagen - Wikipedia
# Odense - Wikipedia
# Madrid - Wikipedia
# Barcelona - Wikipedia
# Valencia - Wikipedia
# Seville - Wikipedia
# Málaga - Wikipedia
# Tallinn - Wikipedia
# Helsinki - Wikipedia
# Tampere - Wikipedia
# Paris - Wikipedia
# Lyon - Wikipedia
# Toulouse - Wikipedia
# London - Wikipedia
# Leeds - Wikipedia
# Glasgow - Wikipedia
# Liverpool - Wikipedia
# Edinburgh - Wikipedia
# Athens - Wikipedia
# Thessaloniki - Wikipedia
# Zagreb - Wikipedia
# Split, Croatia - Wikipedia
# Budapest - Wikipedia
# Miskolc - Wikipedia
# Debrecen - Wikipedia
# Dublin - Wikipedia
# Cork (city) - Wikipedia
# Rome - Wikipedia
# Milan - Wikipedia
# Naples - Wikipedia
# Turin - Wikipedia
# Florence - Wikipedia
# Venice - Wikipedia
# Luxembourg City - Wikipedia
# Riga - Wikipedia
# Malta, Malta Parish - Wikipedia
# The Hague - Wikipedia
# Amsterdam - Wikipedia
# Rotterdam - Wikipedia
# Utrecht - Wikipedia
# Eindhoven - Wikipedia
# Oslo - Wikipedia
# Bergen - Wikipedia
# Stavanger - Wikipedia
# Warsaw - Wikipedia
# Łódź - Wikipedia
# Kraków - Wikipedia
# Lisbon - Wikipedia
# Porto - Wikipedia
# Braga - Wikipedia
# Coimbra - Wikipedia
# Giroc - Wikipedia
# Bratislava - Wikipedia
# Ljubljana - Wikipedia
# Stockholm - Wikipedia
# Gothenburg - Wikipedia
# Malmö - Wikipedia
# Ankara - Wikipedia
# Adana - Wikipedia

# %% [markdown]
# #### Closing browser instance

# %%
browser.quit() #close the browser instance.

# %% [markdown]
# #### Add coordinates to dataframe corresponding them with the respective city

# %%
# Add the latitude and longitude lists as collumns to the end of the data frame

df = pd.concat([df, pd.Series(latitudes, name= 'Latitude'), pd.Series(longitudes, name= 'Longitude')], axis= 1)

df.head()
# Out:
# C:\Users\Ines Caseiro\AppData\Roaming\Python\Python313\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning:
#
# overflow encountered in cast
#
# C:\Users\Ines Caseiro\AppData\Roaming\Python\Python313\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning:
#
# overflow encountered in cast
#                 City  CityName  Country  Population Density  Population  \
# 1    Vienna, Austria    Vienna  Austria               310.0   2983513.0
# 2  Salzburg, Austria  Salzburg  Austria               243.0    375489.0
# 3  Brussels, Belgium  Brussels  Belgium               681.0   3284548.0
# 4   Antwerp, Belgium   Antwerp  Belgium               928.0   1139663.0
# 5      Gent, Belgium      Gent  Belgium               552.0    645813.0
#
#    Working Age Population   Youth Dependency Ratio  Unemployment Rate  \
# 1                2018818.0               20.093750          10.203125
# 2                 250472.0               20.296875           3.000000
# 3                2137425.0               27.500000          10.703125
# 4                 723396.0               27.703125           6.199219
# 5                 417832.0               24.796875           4.585938
#
#    GDP per Capita  Days of very strong heat stress  ...  \
# 1         55770.0                              3.0  ...
# 2         66689.0                              0.0  ...
# 3         62500.0                              3.0  ...
# 4         57595.0                              3.0  ...
# 5         53311.0                              2.0  ...
#
#   Average Monthly Salary  Avgerage Rent Price  Average Cost of Living  \
# 1                 2500.0               1050.0                  2061.0
# 2                 3200.0               1100.0                  2186.0
# 3                 3350.0               1200.0                  1900.0
# 4                 2609.0                900.0                  1953.0
# 5                 2400.0                827.0                  1200.0
#
#    Last Data Update Year Last Update  Month Last Update  Day Last Update  \
# 1        2024-06-15           2024.0                6.0             15.0
# 2        2023-11-03           2023.0               11.0              3.0
# 3        2023-04-22           2023.0                4.0             22.0
# 4        2024-08-09           2024.0                8.0              9.0
# 5        2023-07-17           2023.0                7.0             17.0
#
#    Number Days Ago    Latitude   Longitude
# 1            526.0  47°48′00″N  13°02′42″E
# 2            751.0  50°50′48″N  04°21′09″E
# 3            946.0  51°13′04″N  04°24′01″E
# 4            471.0  51°03′13″N  03°43′31″E
# 5            860.0  51°12′32″N  03°13′27″E
#
# [5 rows x 21 columns]

# %% [markdown]
# 2. Interactive Map

# %% [markdown]
# ## Data Science In Action
